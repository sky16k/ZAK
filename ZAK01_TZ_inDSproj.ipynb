# %% [markdown]
# <a href="https://colab.research.google.com/github/sky16k/ZAK/blob/main/ZAK01_TZ_inDSproj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #/drive/data

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys
data_path = '/content/data'
try:
    os.symlink('/content/drive/MyDrive/скул/DS/data', data_path)
    sys.path.insert(0,data_path)
except:
    pass
# Then you can install a library, and specify the target.
# !pip install --target=$data_path vk_api_config.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title Generate table

shortcuts = r"""
Action                            Mac         Linux                Windows
Add cursors                       ⌥ ⌘ ↑/↓     Shift Alt ↑/↓        Ctrl Alt ↑/↓
Add cursor on next match          ⌘ D         Ctrl D               Ctrl D
Add cursor on all matches         ⇧ ⌘ L       Shift Ctrl L         Ctrl Shift L
Move line up/down                 ⌥ ↑/↓       Alt ↑/↓              Alt ↑/↓
Copy line up/down                 ⇧ ⌥ ↑/↓     Ctrl Shift Alt ↑/↓   Shift Alt ↑/↓
Delete left                       ⌘ ⌫         Ctrl Backspace       Ctrl Backspace
Delete right                      ⌃ k         (Unset by default)   (Unset by default)
Find with selection               ⌘ E         (Unset by default)   (Unset by default)
Expand/shrink selection           ⇧ ⌃ ⌘ →/←   Shift Alt →/←        Shift Alt →/←
Go to bracket                     ⇧ ⌘ \       Ctrl Shift \         Ctrl Shift \
Replace with next/previous value  ⇧ ⌘ , / .   Ctrl Shift , / .     Ctrl Shift , / .
Transpose letters                 ⌃ T         (Unset by default)   (Unset by default)
"""

import io
import pandas as pd
df = pd.read_csv(io.StringIO(shortcuts), delimiter=' {2,}', engine='python')
df = df.set_index('Action').drop(columns=['Mac'])
df
# Out:
#                                                Linux             Windows
# Action
# Add cursors                            Shift Alt ↑/↓        Ctrl Alt ↑/↓
# Add cursor on next match                      Ctrl D              Ctrl D
# Add cursor on all matches               Shift Ctrl L        Ctrl Shift L
# Move line up/down                            Alt ↑/↓             Alt ↑/↓
# Copy line up/down                 Ctrl Shift Alt ↑/↓       Shift Alt ↑/↓
# Delete left                           Ctrl Backspace      Ctrl Backspace
# Delete right                      (Unset by default)  (Unset by default)
# Find with selection               (Unset by default)  (Unset by default)
# Expand/shrink selection                Shift Alt →/←       Shift Alt →/←
# Go to bracket                           Ctrl Shift \        Ctrl Shift \
# Replace with next/previous value    Ctrl Shift , / .    Ctrl Shift , / .
# Transpose letters                 (Unset by default)  (Unset by default)

# %% [markdown]
# #Домашнее задание

# %% [markdown]
# ## осн. текст

# %% [markdown]
# Домашнее задание «Требования в DS проектах aml»
# Задание
# Вопросы по заданию
# Преподаватель: Алексей Кузьмин
# Возьмите за основу продукт Нетологии — профессию Data Scientist.
#
# Подумайте над ответами на вопросы:
#
# Как бы вы организовали аналитику по этому продукту?
# Сформулируйте 2–3 ключевые метрики продукта.
# Какие данные могут помочь вам в поиске решения?
# Опишите команду для работы с данными для этого продукта.
# Какие сотрудники вам будут нужны?
# Чем они будут заниматься?
# Подготовьте решение к 29 сентября 23:59

# %%
'''
Домашнее задание «Требования в DS проектах aml»
Задание
Вопросы по заданию
Преподаватель: Алексей Кузьмин

Возьмите за основу продукт Нетологии — профессию Data Scientist.

Подумайте над ответами на вопросы:

1. Как бы вы организовали аналитику по этому продукту?
2. Сформулируйте 2–3 ключевые метрики продукта.
3. Какие данные могут помочь вам в поиске решения?
4. Опишите команду для работы с данными для этого продукта.
5. Какие сотрудники вам будут нужны?
6. Чем они будут заниматься?

Подготовьте решение к 29 сентября 23:59
'''

# %% [markdown]
# ## 1. Как бы вы организовали аналитику по этому продукту?

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''

# %% [markdown]
#  во первых, ещё до работы по организации аналитики, нужно пообщаться с представителем заказчика и понять основную и второстепенные цели продукта. конечно, глобальное стремление - увеличение приносимой продуктом прибыли. но конкретные реализации этого могут быть разными. например, возможны такие варианты:
#
# 1. в данный момент как потребитель этого продукта я чувствую сильно просевшую поддержку как в тематическом чате (дискорд-дс-амл), так и в разделе В/О на страницах ДЗ. что сильно подрывает моё доверие к бренду и заставляет искать альтернативы. что в дальнейшем может привести к потере меня как клиента и, как очередное следствие, к снижению доходности продукта в целом. в этом случае можно выдвинуть гипотезу, что нацеленность на снижение времени ответов и высокую результативность этих ответов будет способствовать усилению лояльности клиентов и увеличение общей прибыльности. кроме того, само количество заданий гораздо меньше рассматриваемых тем, и стало редкостью закрепление на практике тем и методов из презентаций. но тут нужна работа методистов.
#
# 2. с другой стороны, курс оплачен полностью, пройдена его большая часть, вследствие работы маркетологов, финансистов и юристов возвращать уже ничего не получиться - курс окупился ещё до его окончания. в некотором смысле - это успех! в этом случае, наша модель предполагает низкое "время жизни" клиента и нужно только оценивать работу продажников и эффективность рекламы: воронки переходов, стоимость привлечения клиента (CAC), эффективность каналов и конкретных приёмов в рекламных кампаниях, и в конечном счете - прибыль с 1 пользователя. значит конкретной целью будет улучшение этих показателей. /*кстати, в этом случае, я бы рекомендовал оценить ёмкость рынка для такого нишевого продукта, затем долю конкретно этой его реализации в конкуретной среде и подсчитать как быстро закончаться клиенты на него. (но для реализации такого, кмк, нужны данные каких-нибудь министерств, а то и нескольких, или каких-либо отраслевых ассоциаций, или знать где именно лежат такие данные на сайте росстата - я не смог найти) и как следствие встаёт задача расширения в первую очередь доли продукта в нише (что должно быть привычно), а во вторую - в целом рынка (что весьма нетривиально и требует больших усилий и вложений).*/ при таком подходе на лояльность клиентов и, следовательно, сарафанное радио расчитывать не приходиться - только агрессивные действия в инфополе. хотя, скорее всего, я плохо разбираюсь в маркетинге. и вот тут-то и поможет (ещё раз) представитель заказчика.

# %% [markdown]
# собственно, первый вариант совсем не исключает цели второго варианта, только расчитать коммерческие метрики с учетом большого "времени жизни" клиента будет сложнее. положим, что цели второго варианта актуальны на период становления компании и запуска продукта. а цели первого варианта - во время дальнейшего развития и поиска методов увеличения своей доли рынка как раз за счет лучшего сервиса, увеличения "времени жизни" клиентов, LTV (lifetime value,  жизненной ценности клиента) и, как следствие, отношения ltv/CAC. которое во втором варианте вообще не имело смысла.
#
# поэтому для первого варианта будем считать, что метрики второго варианта уже считаются в отлаженном режиме и нет смысла отдельно на них отвлекаться

# %% [markdown]
# отметим ещё, что вариант 1 больше тяготеет к временнЫм и качественным показателям работы в самой компании ('отделы' 'контроля качества' и 'поддержки клиентов'), а вариант 2 - к коммерческим и маркетинговым на входе в компанию ('отделы' рекламы и продаж).

# %% [markdown]
# Итак, с целями определились.

# %% [markdown]
# продолжим общаться с заказчиком и высним, какими аппаратными и программными средствами в текущий момент осуществляется сбор, хранение и обработка данных, какие метрики уже считаются и можно ли применить их для достижения поставленных целей. на основании этого определить:
# - нужно ли вводить дополнительные метрики? (какие?)
# - понадобятся ли для этого новые данные? (какие?) или какого качества нужные имеющиеся данные?
# - откуда можно взять такие данные? или как улучшить качество имеющихся?
# - нужно ли вводить отдельные сервисы? и выделенные сервера под них? (решить с привлечением технических специалистов)
# - есть ли в компании специалисты для поддержания работы сервисов/серверов после завершения работы аналитиков?
#
# обозначив круг задач, можно приступать к построению схемы движения данных и примерно определить роли, необходимые для обеспечения этого движения. затем, по обозначенным ролям определить степень нагрузки на них и возможность совмещения ролей в одном или нескольких взаимодополняющих сотрудниках.
#
# на разных этапах разработки решения возможно привлечение разных специалистов и стоит заранее понимать потребности в этом и заблаговременно выделить им время для работы над проектом.

# %% [markdown]
# ##2. Сформулируйте 2–3 ключевые метрики продукта.

# %% [markdown]
# 1. для реализации цели по варианту 1 стоит:
# - учитывать как быстро после появления вопроса появляется ответ эксперта. назовем такую метрику "время ответа".
#
# - также следует отслеживать как быстро после ответа появляется готовая работа и как она оценивается экспертом (1-зачет или 0-требует доработки/незачет). для этого возьмём оценку и разделим на затраченное время. назовём такую метрику "эффективность ответа". /*отметим, что "эффективность" предполагает прямую зависимость с качеством и обратную с потерями, поэтому при построении модели и прогнозировании результатов, возможно, будет удобнее использовать величину, обратную к данной метрике.*/
#
# - и в конце попытаться оценить как высокая "эффективность ответа" и низкое "время ответа" влияет на прибыль компании с одного клиента, то есть на отношение ltv/CAC, которое назовём "итоговая прибыльность клиента"
#
# последнюю метрику можно взять из "уже работающей" системы оценки коммерческой эффективности (возможно удасться провести A/B-тест, но это представляется весьма сложным и долгим мероприятием).
# 2 первые метрики вводяться впервые и под них, видимо, придётся развернуть отдельный сервис.

# %% [markdown]
# 2. для реализации цели по варианту 2 стоит учитывать все эти маркетинго-коммерческие метрики:
# - UA — User Acquisition
# - AC — Acquisition Cost
# - CpA — Сost per Acquisition (user acquisition cost)
# - CR — Conversion Rate
# - CAC — Customer Acquisition Cost
# - COGS — Cost Of Goods Sold
# - ARpC — Average Revenue per Customer
# - ARpU — Average Revenue per User
# - AGPpU — Average Gross Profit per User
#
# главной целевой выберем "Среднюю прибыль с пользователя", как включающую в себя всю работу компании от привлечения в рекламе до расходов на прочую операционную деятельность.
#
# как показатель работы отдела продаж возьмём "конверсию"
#
# а показателем эффективности отдела маркетинга - "стоимость пользователя" (в кампаниях - CpA)
#
# полезным будет иметь на виду дополнительно две интегральные метрики:
# - "стоимость привлечения клиента" как итог работы отделов маркетинга и продаж вместе
# - и "себестоимость" единицы продукта, как итог работы всех остальных отделов
#
# вся эта система, видимо, вводится в рамках данного продукта впервые.

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''
# Out:
# '\n\n'

# %% [markdown]
# ## 3. Какие данные могут помочь вам в поиске решения?

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''
# Out:
# '\n\n'

# %% [markdown]
# 1. для начала необходимо иметь доступ к чату дискорд и внутренней системе нетологии. в конце понадобится выписка из системы оценки коммерческой эффективности для отслеживания верности гипотезы.
#
# нужно будет уметь отслеживать время определённых событий (появление вопроса, ответ эксперта, повторный (уточняющий) вопрос, последний ответ эксперта в ветке, загрузка готовых ДР, оценка экспертом ДР, загрузка доработанной ДР), определять категорию автора этих событий (студент/эксперт) и характер этих событий (начало вопроса, уточнение, последний ответ, "зачет" или "доработка/незачет") и конечно нужно однозначно сопоставить авторов на сайте с авторами в дискорде.
#
#
#
# в начале для простоты:
# - будем иметь только 2 категории пользователей: студенты и эксперты;
# - любое сообщение студента будем считать вопросом, а эксперта - ответом.
#
# для сбора и обработки таких данных необходимо будет создать и наладить работу нескольких сервисов:
# - "бот" на дискорд-сервере
# - сервис сбора данных из системы нетологии или настроить логирование событий на сервере с одновременным экспортом нужных нам данных
# - непосредственно обработчик данных
# - может даже своя БД (надо смотреть на объем)

# %% [markdown]
# 2. для расчета обозначенных метрик нам потребуются данные из логов серверов нетологии (количество пользователей за исследуемый период (UA), количество новых клиентов (B), стоимость проданных услуг (S)), данные рекламных кампаний (кол-во показов, переходов, стоимость кампании (ACj) -> стоимость клика -  отдельно по каждой j кампании), ФОТ штатных сотрудников (каждый период могут меняться), услуги привлеченных специалистов (общих для нескольких кампаний), затраты на оборудование, ПО и ОС (можно уже в интегрированном виде, тк фокус на продажах)
#
# большая часть таких данных содержится в стандартной выписке по кампаниям (кол-во показов, переходов, стоимость кампании (ACj) -> стоимость клика) или обычной статистике веб-сервиса(количество пользователей за исследуемый период (UA)). часть надо брать из бухгалтерских выписок(количество новых клиентов (B), стоимость проданных услуг (S), ФОТ, затраты на оборудование, ПО и ОС).
#
# для объединения и обработки этих данных понадобится запустить отдельный сервис. вряд ли нагрузка на него будет велика, поэтому развернть его можно будет на том же оборудовании (по крайней мере на первом этапе).

# %% [markdown]
# ## 4 Опишите команду для работы с данными для этого продукта.

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''
# Out:
# '\n\n'

# %% [markdown]
# 1.
# по полученному перечню данных и сервисов можно примерно наметить необходимые роли в проекте:
# - etl-специалист или дата-инженер будет первоочередной потребностью для сбора данных из разных источников
# - разработчик ПО для создания "бота" - весьма специфичный навык, возможно, следует поискать на аутсорсе
# - возможно потребуется специалист по БД для создания отдельной БД для разрабатываемых сервисов (нужна консультация специалистов)
# - непосредственно аналитик данных для разработки методов обработки данных и подсчета метрик
# - BI-специалист для подготовки итоговых визуализаций в удобной для заказчика форме
# - ближе к концу разработки нужен специалист по размещению проектов в качестве сервисов
# - также к концу разработки нужно проконсультироваться со специалистом по аппаратному обеспечению для решения вопроса о необходимости выделения сервера
# - представитель заказчика для понимания потребностей "бизнеса" и оперативного решения вопросов доступа к данным и техническим возможностям заказчика
# - руководитель проекта для связи участников друг с другом (и с "бизнесом") и выработки оптимальных решений

# %% [markdown]
# 2.
# по полученному перечню данных и сервисов можно примерно наметить необходимые роли в проекте:
# - etl-специалист или дата-инженер будет первоочередной потребностью для сбора данных из разных источников
# - непосредственно аналитик данных для разработки методов обработки данных и подсчета метрик
# - BI-специалист для подготовки итоговых визуализаций в удобной для заказчика форме
# - представитель заказчика для понимания потребностей "бизнеса" и оперативного решения вопросов доступа к данным и техническим возможностям заказчика
# - руководитель проекта для связи участников друг с другом и выработки оптимальных решений

# %% [markdown]
# ## 5. Какие сотрудники вам будут нужны?

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''

# %% [markdown]
# 1. по списку ролей и учитывая предполагаемую сложность работ построим список вакансий нашего проекта:
# - дата-инженеров понадобиться как минимум 2: один для наладки обработки потока с дискорд-сервера, второй для наладки обработки потока с сервера нетологии (или для настройки работы сервиса логгирования самого сервера)
# - разработчика "бота", как уже было сказано, можно поискать на фрилансе или заказать на аутсорсе
# - также на аутсорсе необходимо будет получить консультацию о необходимости БД и по её итогу принять решение о введении должности разработчика БД
# - дата-аналитик естесственно необходим. для начала установим 2 вакансии. к концу один дополнительно займется размещением сервиса как готового решения. а второй,возможно, переключится на визуализацию
# - на аутсорсе консультируемся по поводу выделенных серверов под наши сервисы (и может быть БД)
# - руководитель проекта совершенно необходим, особенно ввиду наличия позиций на аутсорсе. также на эту должность хорошо бы отдать роль BI ввиду большей связи с "бизнесом", понимания возможностей команды и возможности устанавливать стандарты работы и взаимосвязей в этой команде (в частности то, в каком виде будут обмениваться данными сервисы внутри проекта)
# - если никто из аналитиков не умеет в сервисы, берем ещё разработчика
# - если руководитель не может в BI, а аналитики заняты или тоже не специалисты в этом - берем на фрилансе

# %% [markdown]
# 2. по списку ролей и учитывая предполагаемую сложность работ построим список вакансий нашего проекта:
# - дата-инженеров понадобиться как минимум 2: один для наладки обработки потока с сервера нетологии (или для настройки работы сервиса логгирования самого сервера) и из кампаний, второй для наладки потока с бухгалтерии (скорее всего нужны знания 1С, но лучше воспользоваться штатными специалистами заказчика и получать данные уже выгруженные из системы)
# - дата-аналитик естесственно необходим. для начала установим 1 вакансию.
# - руководитель проекта. также на эту должность хорошо бы отдать роль BI ввиду большей связи с "бизнесом", понимания возможностей команды и возможности устанавливать стандарты работы и взаимосвязей в этой команде (в частности то, в каком виде будут обмениваться данными сервисы внутри проекта)
# - если руководитель не может в BI - берем на фрилансе

# %% [markdown]
# ## 6. Чем они будут заниматься?

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''

# %% [markdown]
# 1.
# - разработчик "бота" создает программу для логгирования сообщений на определённом пуле каналов сервера 'DS Netology' и организует выгрузку их в определённом формате с обязательным указанием времени и автора
# - дата-инженер 1 формирует поток данных идущий от "бота", переформатирует данные при необходимости, добавляет метки категорий авторов,
# - дата-инженер 2 при наличии сотрудничества со стороны заказчика настраивает работу сервиса логгирования сервера нетологии для:
# вывода событий о появлении вопроса, ответа эксперта, повторного (уточняющего) вопрос, последнего ответа эксперта в ветке, загрузке готовых ДР, оценке экспертом ДР, загрузке доработанной ДР;
# определения категории авторов этих событий (студент/эксперт);
# определения характера этих событий (начало вопроса, уточнение, последний ответ, "зачет" или "доработка/незачет").
# если содействия мало, то организует сбор данных самостоятельно, но доступ к БД сообщений, событий и списков участников с их категориями необходим в любом случае.
# после формирует форматированный поток данных для применения в аналитике
# - специалист БД оценивает объем потоков и выносит решение о формировании отдельной БД и занимается её настройкой.
# - дата-аналитики работают над созданием алгоритма подсчета метрик и вывода результатов.
# - дата-аналитик 1 в конце формирует результат работы в виде отдельного сервиса.
# - дата-аналитик 2 в конце формирует наглядную визуализацию результатов работы
# - специалист по аппаратному обеспечению (на аутсорсе) оценивает нагрузку, создаваемую сервисами, и выносит решение о необходимости выделенных серверов под наши сервисы (и может быть БД)
# - руководитель проекта
#
# организует связь участников друг с другом (и с "бизнесом") и вырабатывает оптимальные решения
#
#
# совершенно необходим, особенно ввиду наличия позиций на аутсорсе. также на эту должность хорошо бы отдать роль BI ввиду большей связи с "бизнесом", понимания возможностей команды и возможности устанавливать стандарты работы и взаимосвязей в этой команде (в частности то, в каком виде будут обмениваться данными сервисы внутри проекта)
# - если руководитель не может в BI - берем на фрилансе

# %% [markdown]
# ###программа

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Теория
